# %% [markdown]
# # Pandas Project

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Latest Covid-19 India Status.csv')

# %%
data
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7584       8        7447
# 1                             Andhra Pradesh      2030849   14652     2002187
# 2                          Arunachal Pradesh        53807     533       53004
# 3                                      Assam       595669    5615      584296
# 4                                      Bihar       725833      77      716098
# 5                                 Chandigarh        65160      32       64311
# 6                               Chhattisgarh      1004902     376      990968
# 7   Dadra and Nagar Haveli and Daman and Diu        10670       5       10661
# 8                                      Delhi      1438250     377     1412790
# 9                                        Goa       174891     702      170972
# 10                                   Gujarat       825629     161      815386
# ...

# %% [markdown]
# ##### Q1. Print First And Last 10 Values From The Dataframe

# %%
data.head(10)
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar         7584       8        7447
# 1                            Andhra Pradesh      2030849   14652     2002187
# 2                         Arunachal Pradesh        53807     533       53004
# 3                                     Assam       595669    5615      584296
# 4                                     Bihar       725833      77      716098
# 5                                Chandigarh        65160      32       64311
# 6                              Chhattisgarh      1004902     376      990968
# 7  Dadra and Nagar Haveli and Daman and Diu        10670       5       10661
# 8                                     Delhi      1438250     377     1412790
# 9                                       Goa       174891     702      170972
#
#    Deaths  Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# ...

# %%
data.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 31      Telengana       661866    5253      652716    3897              0.79
# 32        Tripura        83672     485       82382     805              0.58
# 33  Uttar Pradesh      1709555     175     1686497   22883              0.01
# 34    Uttarakhand       343242     293      335560    7389              0.09
# 35    West Bengal      1557414    8096     1530731   18587              0.52
#
#     Discharge Ratio (%)  Death Ratio (%)
# 31                98.62             0.59
# 32                98.46             0.96
# 33                98.65             1.34
# 34                97.76             2.15
# 35                98.29             1.19

# %% [markdown]
# ##### Q2. How many Rows & Columns in Dataframe?

# %%
data.shape
# Out:
# (36, 8)

# %%
len(data.index)
# Out:
# 36

# %%
len(data.columns)
# Out:
# 8

# %% [markdown]
# ##### Q3. Display Data Types Of Each Column.

# %%
data.dtypes
# Out:
# State/UTs               object
# Total Cases              int64
# Active                   int64
# Discharged               int64
# Deaths                   int64
# Active Ratio (%)       float64
# Discharge Ratio (%)    float64
# Death Ratio (%)        float64
# dtype: object

# %% [markdown]
# ##### Q4. Find Out The State Whuch Has Minimum Total Cases.

# %%
data.loc[data['Total Cases'].idxmin()] #return index of min. Value.
# Out:
# State/UTs              Andaman and Nicobar
# Total Cases                           7584
# Active                                   8
# Discharged                            7447
# Deaths                                 129
# Active Ratio (%)                      0.11
# Discharge Ratio (%)                  98.19
# Death Ratio (%)                        1.7
# Name: 0, dtype: object

# %% [markdown]
# ##### Q5. Find Out The State Which Has Maximum Total Cases.

# %%
data.loc[data['Total Cases'].idxmax()]
# Out:
# State/UTs              Maharashtra
# Total Cases                6500617
# Active                       53427
# Discharged                 6309021
# Deaths                      138169
# Active Ratio (%)              0.82
# Discharge Ratio (%)          97.05
# Death Ratio (%)               2.13
# Name: 20, dtype: object

# %% [markdown]
# ##### Q6.Display All States Of India From DataFrame

# %%
data['State/UTs']
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %% [markdown]
# ##### Q7. Display All The Data Of States Having Deaths Greater Than 10000.

# %%
data[data['Deaths']>10000]
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 1   Andhra Pradesh      2030849   14652     2002187   14010              0.72
# 6     Chhattisgarh      1004902     376      990968   13558              0.04
# 8            Delhi      1438250     377     1412790   25083              0.03
# 10         Gujarat       825629     161      815386   10082              0.02
# 15       Karnataka      2962408   16269     2908622   37517              0.55
# 16          Kerala      4390489  209335     4158504   22650              4.77
# 19  Madhya Pradesh       792353     131      781705   10517              0.02
# 20     Maharashtra      6500617   53427     6309021  138169              0.82
# 27          Punjab       601072     309      584306   16457              0.05
# 30      Tamil Nadu      2635419   16522     2583707   35190              0.63
# 33   Uttar Pradesh      1709555     175     1686497   22883              0.01
# ...

# %% [markdown]
# ##### Q8. Count The Total Cases Of India.

# %%
data['Total Cases'].sum()
# Out:
# 33289579

# %% [markdown]
# ##### Q9. What is the Death Ratio Of Maharashtra?

# %%
data['Death Ratio (%)'][20]
# Out:
# 2.13

# %% [markdown]
# ##### Q10. Which State Has Minimum Death Ratio?

# %%
data.loc[data['Death Ratio (%)'].idxmin()]
# Out:
# State/UTs              Dadra and Nagar Haveli and Daman and Diu
# Total Cases                                               10670
# Active                                                        5
# Discharged                                                10661
# Deaths                                                        4
# Active Ratio (%)                                           0.05
# Discharge Ratio (%)                                       99.92
# Death Ratio (%)                                            0.04
# Name: 7, dtype: object

# %% [markdown]
# ##### Q11. Find Out The Discharged Patients From The States Maharashtra,Karnataka,MP,Gujrat.

# %%
print('Discharged Patients Of Maharashtra',data['Discharged'][20])
print('Discharged Patirents Of Karnataka',data['Discharged'][15])
print('Discharged Patirents Of MP',data['Discharged'][19])
print('Discharged Patirents Of Gujrat',data['Discharged'][10])
# Out:
# Discharged Patients Of Maharashtra 6309021
# Discharged Patirents Of Karnataka 2908622
# Discharged Patirents Of MP 781705
# Discharged Patirents Of Gujrat 815386

# %% [markdown]
# ##### Q12. Find Out The States Having Total Cases between 1lac to 5lac.

# %%
data[data['Total Cases'].between(100000,500000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  \
# 9                 Goa       174891     702      170972    3217
# 12   Himachal Pradesh       215893    1521      210733    3639
# 13  Jammu and Kashmir       326990    1247      321329    4414
# 14          Jharkhand       348079     117      342829    5133
# 21            Manipur       117230    2617      112801    1812
# 26         Puducherry       124836     860      122153    1823
# 34        Uttarakhand       343242     293      335560    7389
#
#     Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 9               0.40                97.76             1.84
# 12              0.70                97.61             1.69
# 13              0.38                98.27             1.35
# 14              0.03                98.49             1.47
# 21              2.23                96.22             1.55
# 26              0.69                97.85             1.46
# ...

# %% [markdown]
# ##### Q13. Display All The Data Of The States Which Has Active Cases Less Than 1000.

# %%
data[data['Active']<1000]
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7584       8        7447
# 2                          Arunachal Pradesh        53807     533       53004
# 4                                      Bihar       725833      77      716098
# 5                                 Chandigarh        65160      32       64311
# 6                               Chhattisgarh      1004902     376      990968
# 7   Dadra and Nagar Haveli and Daman and Diu        10670       5       10661
# 8                                      Delhi      1438250     377     1412790
# 9                                        Goa       174891     702      170972
# 10                                   Gujarat       825629     161      815386
# 11                                   Haryana       770659     351      760501
# 14                                 Jharkhand       348079     117      342829
# ...

# %% [markdown]
# ##### Q14. Make A Separate CSV File Of Q13.

# %%
data[data['Active']<1000].to_csv('newdata.csv')

# %% [markdown]
# ##### Q15. Total Number Of Deaths In India.

# %%
print('Total Number of deaths in India',data['Deaths'].sum())
# Out:
# Total Number of deaths in India 443213
